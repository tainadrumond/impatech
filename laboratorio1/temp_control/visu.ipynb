# %%
import pandas as pd
import altair as alt

# %%
volt = pd.read_csv('./volt.csv')
volt = volt.reset_index().rename(columns={'index': 'tempo'})
volt
# Out:
#       tempo  tensao
# 0         0  2.0772
# 1         1  2.0772
# 2         2  2.0772
# 3         3  2.0772
# 4         4  2.0772
# ...     ...     ...
# 2111   2111  2.5367
# 2112   2112  2.5367
# 2113   2113  2.5367
# 2114   2114  2.5367
# 2115   2115  2.5367
#
# [2116 rows x 2 columns]

# %%
chart = alt.Chart(volt).mark_point().encode(
    alt.X('tempo', scale=alt.Scale(zero=False)),
    alt.Y('tensao', scale=alt.Scale(zero=False))
)
chart
# Out:
# alt.Chart(...)

# %%
temp = pd.read_csv('./temp.csv')
temp = temp.reset_index().rename(columns={'index': 'tempo'})
temp
# Out:
#       tempo      temp
# 0         0  29.39002
# 1         1  29.39002
# 2         2  29.39002
# 3         3  29.39002
# 4         4  29.39002
# ...     ...       ...
# 2111   2111  24.62851
# 2112   2112  24.62851
# 2113   2113  24.62851
# 2114   2114  24.62851
# 2115   2115  24.62851
#
# [2116 rows x 2 columns]

# %%
chart = alt.Chart(temp).mark_point().encode(
    alt.X('tempo', scale=alt.Scale(zero=False)),
    alt.Y('temp', scale=alt.Scale(zero=False))
)
chart
# Out:
# alt.Chart(...)
